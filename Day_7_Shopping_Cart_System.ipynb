# %% [markdown]
# # Day 7 Shopping Cart System

# %%
# Day 7 - Shopping Cart System

total_items = 0
subtotal = 0.0

while True:
    price = float(input("Enter item price (0 to finish): "))

    if price == 0:
        break

    if price < 0:
        print("Negative prices are not allowed. Please enter again.")
        continue

    total_items += 1
    subtotal += price

if subtotal >= 1000:
    discount_rate = 0.20
elif subtotal >= 500:
    discount_rate = 0.10
elif subtotal >= 200:
    discount_rate = 0.05
else:
    discount_rate = 0.0

discount_amount = subtotal * discount_rate
final_total = subtotal - discount_amount

print("\n--- Bill Summary ---")
print("Total number of items:", total_items)
print(f"Subtotal: {subtotal:.2f}")
print(f"Discount: {discount_amount:.2f}")
print(f"Final Total: {final_total:.2f}")
# Out:
# Enter item price (0 to finish): 888
# Enter item price (0 to finish): 777
# Enter item price (0 to finish): 0
#
# --- Bill Summary ---
# Total number of items: 2
# Subtotal: 1665.00
# Discount: 333.00
# Final Total: 1332.00
